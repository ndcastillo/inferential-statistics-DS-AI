# %% [markdown]
# <a href="https://colab.research.google.com/github/ndcastillo/inferential-statistics-DS-AI/blob/main/Funciones_de_Muestreo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Cargamos las librerias necesarias para realizar el análisis.

# %%
import pandas as pd
import numpy  as np
import random
import io

# %% [markdown]
# Leemos la base de datos a trabajar en nuestra ruta de origen.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f77dc08f-1da5-431a-b104-970bca1ed22b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f77dc08f-1da5-431a-b104-970bca1ed22b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Econdata.csv to Econdata.csv

# %%
econdata = pd.read_csv(io.BytesIO(uploaded["Econdata.csv"]))
# Los 5 primeros registros
econdata.head()
# Out:
#    id                  geo_point_2d  \
# 0   0   19.424781053,-99.1327537959
# 1   1  19.4346139576,-99.1413808393
# 2   2  19.4340695945,-99.1306348409
# 3   3      19.42489472,-99.12073393
# 4   4      19.42358238,-99.12451093
#
#                                            geo_shape   clave_cat  \
# 0  {"type": "Polygon", "coordinates": [[[-99.1332...  307_130_11
# 1  {"type": "MultiPoint", "coordinates": [[-99.14...  002_008_01
# 2  {"type": "MultiPoint", "coordinates": [[-99.13...  006_002_12
# 3  {"type": "MultiPoint", "coordinates": [[-99.12...  323_102_06
# 4  {"type": "MultiPoint", "coordinates": [[-99.12...  323_115_12
#
#             delegacion perimetro     tipo  \
# 0           Cuauhtémoc         B  Mercado
# 1            Cuautémoc         A    Museo
# 2            Cuautémoc         A    Museo
# 3  Venustiano Carranza         B    Hotel
# 4  Venustiano Carranza         B    Hotel
#
#                                               nom_id
# 0                                        Pino Suárez
# 1  Museo Nacional de Arquitectura Palacio de Bell...
# 2                                       Santa Teresa
# 3                                           Balbuena
# 4                                               real

# %% [markdown]
# ## Funcion de Muestreo

# %% [markdown]
# ## Muestreo Aleatorio Simple

# %%
aleat_8 = econdata.sample(n=8)
aleat_8
# Out:
#       id                  geo_point_2d  \
# 97    97  19.4440005647,-99.1372278043
# 31    31  19.4242639147,-99.1311619613
# 57    57  19.4303913751,-99.1465372648
# 121  121  19.4303083246,-99.1405735286
# 154  154  19.4245820084,-99.1259208824
# 186  186  19.4275038262,-99.1346778267
# 38    38  19.4439555857,-99.1345196425
# 76    76  19.4367072434,-99.1424407474
#
#                                              geo_shape   clave_cat  \
# 97   {"type": "MultiPoint", "coordinates": [[-99.13...  004_038_04
# 31   {"type": "MultiPoint", "coordinates": [[-99.13...  307_129_20
# 57   {"type": "MultiPoint", "coordinates": [[-99.14...  002_048_10
# 121  {"type": "MultiPoint", "coordinates": [[-99.14...  001_043_15
# 154  {"type": "MultiPoint", "coordinates": [[-99.12...  307_119_06
# 186  {"type": "MultiPoint", "coordinates": [[-99.13...  001_052_24
# 38   {"type": "Polygon", "coordinates": [[[-99.1351...  004_106_01
# 76   {"type": "MultiPoint", "coordinates": [[-99.14...  003_095_02
#
#      delegacion perimetro     tipo                       nom_id
# 97    Cuautémoc         B    Museo            Galeria El Trébol
# 31    Cuautémoc         B    Hotel                     Escorial
# 57    Cuautémoc         B    Hotel                        Conde
# 121   Cuautémoc         A    Hotel                  El Salvador
# 154   Cuautémoc         B    Hotel                    Las Vegas
# 186   Cuautémoc         A    Museo  Casa de la Memoria Indómita
# 38   Cuauhtémoc         B  Mercado     La Lagunilla Comestibles
# 76    Cuautémoc         A    Museo                  Franz Mayer

# %%
aleat_8_2 = econdata.sample(n=8)
aleat_8_2
# Out:
#       id                  geo_point_2d  \
# 210  210      19.43082385,-99.12366058
# 60    60  19.4274816595,-99.1285626779
# 186  186  19.4275038262,-99.1346778267
# 125  125  19.4342350395,-99.1354548065
# 21    21      19.43614459,-99.13945267
# 120  120   19.438089976,-99.1374885065
# 154  154  19.4245820084,-99.1259208824
# 149  149      19.43031663,-99.12465191
#
#                                              geo_shape   clave_cat  \
# 210  {"type": "MultiPoint", "coordinates": [[-99.12...  323_029_08
# 60   {"type": "MultiPoint", "coordinates": [[-99.12...  006_086_10
# 186  {"type": "MultiPoint", "coordinates": [[-99.13...  001_052_24
# 125  {"type": "MultiPoint", "coordinates": [[-99.13...  001_007_06
# 21   {"type": "MultiPoint", "coordinates": [[-99.13...  004_098_01
# 120  {"type": "MultiPoint", "coordinates": [[-99.13...  004_086_24
# 154  {"type": "MultiPoint", "coordinates": [[-99.12...  307_119_06
# 149  {"type": "MultiPoint", "coordinates": [[-99.12...  323_035_01
#
#               delegacion perimetro   tipo                       nom_id
# 210  Venustiano Carranza         B  Hotel                      Hispano
# 60             Cuautémoc         A  Hotel                       Oviedo
# 186            Cuautémoc         A  Museo  Casa de la Memoria Indómita
# 125            Cuautémoc         A  Hotel                       Zamora
# 21             Cuautémoc         A  Museo                    Telégrafo
# 120            Cuautémoc         A  Hotel          Atlanta, S. DE R.L.
# 154            Cuautémoc         B  Hotel                    Las Vegas
# 149  Venustiano Carranza         B  Hotel                    Liverpool

# %%
prop_25 = econdata.sample(frac=.25)
print('Dataframe de longitud de '+str(len(prop_25)))

prop_25.head()
# Out:
# Dataframe de longitud de 58
#       id                  geo_point_2d  \
# 135  135  19.4300009578,-99.1430773295
# 61    61   19.4343847692,-99.125125489
# 226  226  19.4416748524,-99.1365878489
# 190  190      19.43311885,-99.14512643
# 99    99  19.4438918423,-99.1402516182
#
#                                              geo_shape   clave_cat  \
# 135  {"type": "Polygon", "coordinates": [[[-99.1431...  002_045_01
# 61   {"type": "Polygon", "coordinates": [[[-99.1257...  005_140_01
# 226  {"type": "Polygon", "coordinates": [[[-99.1370...  004_052_01
# 190  {"type": "MultiPoint", "coordinates": [[-99.14...  002_019_02
# 99   {"type": "MultiPoint", "coordinates": [[-99.14...  003_052_18
#
#      delegacion perimetro     tipo                       nom_id
# 135  Cuauhtémoc         B  Mercado  Centro Artesanal "San Juan"
# 61   Cuauhtémoc         B  Mercado                     Mixcalco
# 226  Cuauhtémoc         B  Mercado                   De Muebles
# 190   Cuautémoc         B    Hotel                     Metropol
# 99    Cuautémoc         B    Hotel                     Drigales

# %% [markdown]
# ## Muestreo Sistematico

# %%
def systematic_sampling(econdata,step):
  indexes = np.arange(0,len(econdata),step=step)
  systematic_sample = econdata.iloc[indexes]
  return systematic_sample

systematic_sample = systematic_sampling(econdata, 3)
print('El datafame con muestreo sistematico tiene una longitud de '+str(len(systematic_sample)))
systematic_sample.head()
# Out:
# El datafame con muestreo sistematico tiene una longitud de 77
#     id                  geo_point_2d  \
# 0    0   19.424781053,-99.1327537959
# 3    3      19.42489472,-99.12073393
# 6    6      19.43553422,-99.12324801
# 9    9  19.4407152937,-99.1498060057
# 12  12      19.43990186,-99.14813347
#
#                                             geo_shape   clave_cat  \
# 0   {"type": "Polygon", "coordinates": [[[-99.1332...  307_130_11
# 3   {"type": "MultiPoint", "coordinates": [[-99.12...  323_102_06
# 6   {"type": "MultiPoint", "coordinates": [[-99.12...  318_116_11
# 9   {"type": "MultiPoint", "coordinates": [[-99.14...  012_146_22
# 12  {"type": "MultiPoint", "coordinates": [[-99.14...  003_079_16
#
#              delegacion perimetro     tipo                nom_id
# 0            Cuauhtémoc         B  Mercado           Pino Suárez
# 3   Venustiano Carranza         B    Hotel              Balbuena
# 6   Venustiano Carranza         B    Hotel  San Antonio Tomatlan
# 9             Cuautémoc         B    Hotel               Detroit
# 12            Cuautémoc         B    Hotel                La Paz

# %% [markdown]
# ## Muestreo Estratificado

# %%
econdata['estratificado'] = econdata['delegacion']+","+econdata['tipo']
(econdata['estratificado'].value_counts()/len(econdata)).sort_values(ascending=False)
# Out:
# 0             Cuauhtémoc,Mercado
# 1                Cuautémoc,Museo
# 2                Cuautémoc,Museo
# 3      Venustiano Carranza,Hotel
# 4      Venustiano Carranza,Hotel
#                  ...
# 225    Venustiano Carranza,Hotel
# 226           Cuauhtémoc,Mercado
# 227           Cuauhtémoc,Mercado
# 228              Cuautémoc,Museo
# 229              Cuautémoc,Museo
# Name: estratificado, Length: 230, dtype: object
# Cuautémoc,Hotel                0.643478
# Cuautémoc,Museo                0.156522
# Venustiano Carranza,Hotel      0.078261
# Cuauhtémoc,Mercado             0.073913
# Venustiano Carranza,Mercado    0.047826
# Name: estratificado, dtype: float64

# %% [markdown]
# Nuestros datos dicen que la proporción es la siguiente:
#
# 1) Hoteles en Cuauhtemoc es el 0.5
#
# 2) Los Museos en Cuauhtemoc es el 0.2
#
# 3) Hoteles en Venustiano Carranza  es del 0.1
#
# 4) Mercados en Cuauhtemoc 0.1
#
# 5) Mercados en Venustiano Carranza son el 0.1

# %%
def data_estratificada(econdata,nombres_columnas_estrat, valores_estrat, prop_estrat, random_state=None):

  df_estrat = pd.DataFrame(columns = econdata.columns)

  pos = -1
  for i in range(len(valores_estrat)):
    pos += 1
    if pos == len(valores_estrat) - 1:
      ratio_len = len(econdata) - len(df_estrat)
    else:
      ratio_len = int(len(econdata) * prop_estrat[i])
  
    df_filtrado = econdata[econdata[nombres_columnas_estrat] == valores_estrat[i]]
    df_temp = df_filtrado.sample(replace=True, n=ratio_len, random_state=random_state)
    
    df_estrat = pd.concat([df_estrat, df_temp])
  
  return df_estrat

valores_estrat = ['Cuautémoc,Hotel', 'Cuautémoc,Museo', 'Venustiano Carranza,Hotel', 'Cuauhtémoc,Mercado','Venustiano Carranza,Mercado']
prop_estrat = [0.5, 0.2, 0.1, 0.1, 0.1]
df_estrat = data_estratificada(econdata, 'estratificado', valores_estrat, prop_estrat, random_state=42)
df_estrat
# Out:
#       id                  geo_point_2d  \
# 164  164  19.4388741511,-99.1413308257
# 142  142  19.4263681354,-99.1327278126
# 27    27  19.4348360773,-99.1463945583
# 168  168   19.4349726565,-99.147766133
# 113  113      19.43374405,-99.13550135
# ..   ...                           ...
# 128  128  19.4270781084,-99.1210175514
# 37    37   19.4271233834,-99.125111772
# 163  163  19.4265454033,-99.1224859032
# 156  156  19.4255480371,-99.1249308096
# 37    37   19.4271233834,-99.125111772
#
#                                              geo_shape        clave_cat  \
# 164  {"type": "MultiPoint", "coordinates": [[-99.14...       003_113_03
# 142  {"type": "MultiPoint", "coordinates": [[-99.13...       006_127_14
# 27   {"type": "MultiPoint", "coordinates": [[-99.14...       002_016_01
# 168  {"type": "MultiPoint", "coordinates": [[-99.14...       002_014_23
# 113  {"type": "MultiPoint", "coordinates": [[-99.13...       001_012_13
# ..                                                 ...              ...
# 128  {"type": "Polygon", "coordinates": [[[-99.1214...  323_061_04(123)
# 37   {"type": "Polygon", "coordinates": [[[-99.1251...       323_065_01
# 163  {"type": "Polygon", "coordinates": [[[-99.1231...       323_063_05
# 156  {"type": "Polygon", "coordinates": [[[-99.1253...   323_138_04 (3)
# 37   {"type": "Polygon", "coordinates": [[[-99.1251...       323_065_01
#
#               delegacion perimetro     tipo                   nom_id  \
# 164            Cuautémoc         B    Hotel             Dos Naciones
# 142            Cuautémoc         A    Hotel                    Ambar
# 27             Cuautémoc         B    Hotel  Hilton Centro Histórico
# 168            Cuautémoc         B    Hotel              One Alameda
# 113            Cuautémoc         A    Hotel              San Antonio
# ..                   ...       ...      ...                      ...
# 128  Venustiano Carranza         B  Mercado              San Ciprian
# 37   Venustiano Carranza         B  Mercado                 Dulceria
# 163  Venustiano Carranza         B  Mercado                      NaN
# 156  Venustiano Carranza         B  Mercado                 Mariscos
# 37   Venustiano Carranza         B  Mercado                 Dulceria
#
#                    estratificado
# 164              Cuautémoc,Hotel
# 142              Cuautémoc,Hotel
# 27               Cuautémoc,Hotel
# 168              Cuautémoc,Hotel
# 113              Cuautémoc,Hotel
# ..                           ...
# 128  Venustiano Carranza,Mercado
# 37   Venustiano Carranza,Mercado
# 163  Venustiano Carranza,Mercado
# 156  Venustiano Carranza,Mercado
# 37   Venustiano Carranza,Mercado
#
# [230 rows x 9 columns]
